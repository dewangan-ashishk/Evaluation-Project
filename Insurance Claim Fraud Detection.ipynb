# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('Automobile_insurance_fraud.csv')

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
#All the values in the column '_c39' have missing values. lets drop that column
df.drop('_c39',axis=1,inplace=True)

# %%
df.head(50)
# Out:
#     months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                  328   48         521585       17-10-2014           OH
# 1                  228   42         342868       27-06-2006           IN
# 2                  134   29         687698       06-09-2000           OH
# 3                  256   41         227811       25-05-1990           IL
# 4                  228   44         367455       06-06-2014           IL
# 5                  256   39         104594       12-10-2006           OH
# 6                  137   34         413978       04-06-2000           IN
# 7                  165   37         429027       03-02-1990           IL
# 8                   27   33         485665       05-02-1997           IL
# 9                  212   42         636550       25-07-2011           IL
# 10                 235   42         543610       26-05-2002           OH
# 11                 447   61         214618       29-05-1999           OH
# ...

# %%
df.isna().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...

# %%
# identify variables with '?' values
unknowns = {}
for i in list(df.columns):
    if (df[i]).dtype == object:
        j = np.sum(df[i] == "?")
        unknowns[i] = j
unknowns = pd.DataFrame.from_dict(unknowns, orient = 'index')
print(unknowns)
# Out:
#                            0
# policy_bind_date           0
# policy_state               0
# policy_csl                 0
# insured_sex                0
# insured_education_level    0
# insured_occupation         0
# insured_hobbies            0
# insured_relationship       0
# incident_date              0
# incident_type              0
# collision_type           178
# incident_severity          0
# authorities_contacted      0
# incident_state             0
# incident_city              0
# incident_location          0
# property_damage          360
# police_report_available  343
# auto_make                  0
# auto_model                 0
# fraud_reported             0

# %%
#in the column 'collision_type', ? is used in case of vehicle theft or when car is parked. Lets replace the ? with no collision
df['collision_type'].replace('?','No Collision', inplace=True)

# %%
df['property_damage'].replace('?','No', inplace=True)

# %%
df['police_report_available'].replace('?','No', inplace=True)

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %%
df['fraud_reported'].value_counts()
# Out:
# N    753
# Y    247
# Name: fraud_reported, dtype: int64

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
table=pd.crosstab(df.age, df.fraud_reported)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Age vs Fraud Reported', fontsize=12)
plt.xlabel('Age')
plt.ylabel('Fraud reported')
plt.show()

# %% [markdown]
# majority of the frauds are reported by person of age 19 and 22

# %%
plt.figure(figsize=(15,10))
table=pd.crosstab(df.insured_sex, df.fraud_reported)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Sex vs Fraud Reported', fontsize=12)
plt.xlabel('insured_sex')
plt.ylabel('Fraud reported')
plt.show()

# %% [markdown]
# fraud reported by male and female lie are in close proportion

# %%
plt.figure(figsize=(15,10))
table=pd.crosstab(df.insured_education_level, df.fraud_reported)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Education Level vs Fraud Reported', fontsize=12)
plt.xlabel('insured_education_level')
plt.ylabel('Fraud reported')
plt.show()

# %% [markdown]
# fraud reported is spread across all education levels

# %%
plt.figure(figsize=(15,10))
table=pd.crosstab(df.insured_occupation, df.fraud_reported)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Occupation vs Fraud Reported', fontsize=12)
plt.xlabel('insured_occupation')
plt.ylabel('Fraud reported')
plt.show()

# %%
plt.figure(figsize=(15,10))
table=pd.crosstab(df.incident_type, df.fraud_reported)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Incident Type vs Fraud Reported', fontsize=12)
plt.xlabel('incident_type')
plt.ylabel('Fraud reported')
plt.show()

# %%
plt.figure(figsize=(15,10))
table=pd.crosstab(df.collision_type, df.fraud_reported)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Collision Type vs Fraud Reported', fontsize=12)
plt.xlabel('collision_type')
plt.ylabel('Fraud reported')
plt.show()

# %%
plt.figure(figsize=(15,10))
table=pd.crosstab(df.incident_severity, df.fraud_reported)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Incident Severity vs Fraud Reported', fontsize=12)
plt.xlabel('incident_severity')
plt.ylabel('Fraud reported')
plt.show()

# %%
plt.figure(figsize=(15,10))
table=pd.crosstab(df.authorities_contacted, df.fraud_reported)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Authporities Contacted vs Fraud Reported', fontsize=12)
plt.xlabel('authorities_contacted')
plt.ylabel('Fraud reported')
plt.show()

# %% [markdown]
# Majority of fraud is reported when there is a Major Damage

# %%
plt.figure(figsize=(15,10))
table=pd.crosstab(df.witnesses, df.fraud_reported)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Witnesses vs Fraud Reported', fontsize=12)
plt.xlabel('witnesses')
plt.ylabel('Fraud reported')
plt.show()

# %%
plt.figure(figsize=(15,10))
table=pd.crosstab(df.auto_make, df.fraud_reported)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Auto Make vs Fraud Reported', fontsize=12)
plt.xlabel('auto_make')
plt.ylabel('Fraud reported')
plt.show()

# %%
plt.figure(figsize=(15,10))
table=pd.crosstab(df.auto_year, df.fraud_reported)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Auto Year vs Fraud Reported', fontsize=12)
plt.xlabel('auto_year')
plt.ylabel('Fraud reported')
plt.show()

# %% [markdown]
# # Data Pre-processing

# %%
df['fraud_reported'].replace(to_replace='Y', value=1, inplace=True)
df['fraud_reported'].replace(to_replace='N',  value=0, inplace=True)

# %%
df[['insured_zip']] = df[['insured_zip']].astype(object)

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit  capital-gains   capital-loss  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06   25126.100000  -26793.700000
# std               244.167395    2.297407e+06   27872.187708   28104.096686
# ...

# %%
#lets do some feature engineering and find out age of the vehicle
df['vehicle_age'] = 2015 - df['auto_year'] # Deriving the age of the vehicle based on the incident year 
df['vehicle_age'].head()
# Out:
# 0    11
# 1     8
# 2     8
# 3     1
# 4     6
# Name: vehicle_age, dtype: int64

# %%
#lets find out time of day from the incident hour
bins = [-1, 3, 6, 9, 12, 16, 20, 24]  # Factorize according to the time period of the day.
names = ["past_midnight", "early_morning", "morning", 'fore-noon', 'afternoon', 'evening', 'night']
df['incident_period_of_day'] = pd.cut(df.incident_hour_of_the_day, bins, labels=names).astype(object)
df[['incident_hour_of_the_day', 'incident_period_of_day']].head()
# Out:
#    incident_hour_of_the_day incident_period_of_day
# 0                         5          early_morning
# 1                         8                morning
# 2                         7                morning
# 3                         5          early_morning
# 4                        20                evening

# %%
corr=df.corr().abs()
plt.figure(figsize=(22,16))
sns.heatmap(corr, vmin=-1,vmax=1, annot=True,
            square=True, center=0, fmt='.2g')
plt.tight_layout()

# %% [markdown]
# Number of vehicles involved is corelated to incident_type
# Also total claim amount is corelated to injury_claim, property claim and vehicle claim
# so we can drop these columns

# %%
df.drop(['incident_type','injury_claim', 'property_claim', 'vehicle_claim'],axis=1, inplace=True)

# %%
numerics=['int8','int16','int32','int64','float16','float32','float64']
categorical_columns=[]
features = df.columns.values.tolist()

for col in features:
    if df[col].dtype in numerics:
        continue
    categorical_columns.append(col)
categorical_columns
# Out:
# ['policy_bind_date',
#  'policy_state',
#  'policy_csl',
#  'insured_zip',
#  'insured_sex',
#  'insured_education_level',
#  'insured_occupation',
#  'insured_hobbies',
#  'insured_relationship',
#  'incident_date',
#  'collision_type',
#  'incident_severity',
#  'authorities_contacted',
#  'incident_state',
#  'incident_city',
#  'incident_location',
#  'property_damage',
#  'police_report_available',
#  'auto_make',
#  'auto_model',
#  'incident_period_of_day']

# %%
# dropping unimportant columns

df = df.drop(columns = [
    'policy_state',
    'policy_number', 
    'policy_csl',
    'insured_zip',
    'policy_bind_date', 
    'incident_date', 
    'incident_location', 
    'auto_year', 
    'incident_hour_of_the_day'])

# %%
numerics=['int8','int16','int32','int64','float16','float32','float64']
categorical_columns=[]
features = df.columns.values.tolist()

for col in features:
    if df[col].dtype in numerics:
        continue
    categorical_columns.append(col)
categorical_columns
# Out:
# ['insured_sex',
#  'insured_education_level',
#  'insured_occupation',
#  'insured_hobbies',
#  'insured_relationship',
#  'collision_type',
#  'incident_severity',
#  'authorities_contacted',
#  'incident_state',
#  'incident_city',
#  'property_damage',
#  'police_report_available',
#  'auto_make',
#  'auto_model',
#  'incident_period_of_day']

# %%
#encoding categorical labels
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
for col in categorical_columns:
    df[col]=encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#    months_as_customer  age  policy_deductable  policy_annual_premium  \
# 0                 328   48               1000                1406.91
# 1                 228   42               2000                1197.22
# 2                 134   29               2000                1413.14
# 3                 256   41               2000                1415.74
# 4                 228   44               1000                1583.91
#
#    umbrella_limit  insured_sex  insured_education_level  insured_occupation  \
# 0               0            1                        4                   2
# 1         5000000            1                        4                   6
# 2         5000000            0                        6                  11
# 3         6000000            0                        6                   1
# 4         6000000            1                        0                  11
#
#    insured_hobbies  insured_relationship  capital-gains  capital-loss  \
# ...

# %%
# Divide dataset into features and labels
x=df.drop(['fraud_reported'],axis=1)
y=df['fraud_reported']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.75, random_state=7)

# %% [markdown]
# KNN

# %%
from sklearn import neighbors

print("KNN Score :")
KNN_model = neighbors.KNeighborsClassifier(n_neighbors=12, weights='distance')
KNN_model.fit(X=x_train,y=y_train)
KNN_model.score(x_test,y_test)
# Out:
# KNN Score :
# 0.712

# %%
KNN_y_pred = KNN_model.predict(x_test)
class_names = np.unique(np.array(y_test))
confusion_matrix(y_test, KNN_y_pred)
# Out:
# array([[171,  15],
#        [ 57,   7]], dtype=int64)

# %%
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score

print(classification_report(y_test, KNN_y_pred))

scores = cross_val_score(KNN_model, x, y, cv=10, scoring='accuracy')
knn_accuracy = scores.mean()
print('Cross-Validated Accuracy: %0.2f' % knn_accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83       186
#            1       0.32      0.11      0.16        64
#
#     accuracy                           0.71       250
#    macro avg       0.53      0.51      0.49       250
# weighted avg       0.64      0.71      0.66       250
#
# Cross-Validated Accuracy: 0.73

# %% [markdown]
# DecisionTree

# %%
from sklearn import tree

DT_model = tree.DecisionTreeClassifier()
DT_model.fit(x_train, y_train) 

print("Decision Tree Score :")
DT_model.score(x_test,y_test)
# Out:
# Decision Tree Score :
# 0.78

# %%
DT_y_pred = DT_model.predict(x_test)
class_names = np.unique(np.array(y_test))
confusion_matrix(y_test, DT_y_pred)
# Out:
# array([[152,  34],
#        [ 21,  43]], dtype=int64)

# %%
print(classification_report(y_test, DT_y_pred))

scores = cross_val_score(DT_model, x, y, cv=10, scoring='accuracy')
dt_accuracy = scores.mean()
print('Cross-Validated Accuracy: %0.2f' % dt_accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85       186
#            1       0.56      0.67      0.61        64
#
#     accuracy                           0.78       250
#    macro avg       0.72      0.74      0.73       250
# weighted avg       0.80      0.78      0.79       250
#
# Cross-Validated Accuracy: 0.77

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

RF_model = RandomForestClassifier()
RF_model.fit(x_train, y_train) 
print("Random Forest Score :")
RF_model.score(x_test,y_test)
# Out:
# Random Forest Score :
# 0.764

# %%
RF_y_pred = RF_model.predict(x_test)
class_names = np.unique(np.array(y_test))
confusion_matrix(y_test, RF_y_pred)
# Out:
# array([[159,  27],
#        [ 32,  32]], dtype=int64)

# %%
report = classification_report(y_test, RF_y_pred)
print(report)

scores = cross_val_score(RFClassifier, x, y, cv=10, scoring='accuracy')
rf_accuracy = scores.mean()
print('Cross-Validated Accuracy: %0.2f' % rf_accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       186
#            1       0.54      0.50      0.52        64
#
#     accuracy                           0.76       250
#    macro avg       0.69      0.68      0.68       250
# weighted avg       0.76      0.76      0.76       250
#
# Cross-Validated Accuracy: 0.77

# %% [markdown]
# XGBOOST Classifier

# %%
from xgboost import XGBClassifier

XGB_model = XGBClassifier()
XGB_model.fit(x_train, y_train, verbose=False) 
print("XGBClassifier Score :")
XGB_model.score(x_test,y_test)
# Out:
# [22:40:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier Score :
# 0.796

# %%
xgboost_y_pred = XGB_model.predict(x_test)
report = classification_report(y_test, xgboost_y_pred)

print(report)

scores = cross_val_score(XGB_model, x, y, cv=10, scoring='accuracy')
xgb_accuracy = scores.mean()
print('Cross-Validated Accuracy: %0.2f' % xgb_accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.86       186
#            1       0.58      0.72      0.64        64
#
#     accuracy                           0.80       250
#    macro avg       0.74      0.77      0.75       250
# weighted avg       0.81      0.80      0.80       250
#
# [22:40:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:40:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
#Comparing the models
knn_prob = KNN_model.predict_proba(x_test)[:, 1]
fpr1, tpr1, thresholds2 = roc_curve(y_test, knn_prob)
roc_auc1 = auc(fpr1, tpr1)

fpr2, tpr2, thresholds2 = roc_curve(y_test, DT_y_pred)
roc_auc2 = auc(fpr2, tpr2)

rf_prob = RF_model.predict_proba(x_test)[:, 1]
fpr3, tpr3, thresholds3 = roc_curve(y_test, rf_prob)
roc_auc3 = auc(fpr3, tpr3)

xgb_prob = RF_model.predict_proba(x_test)[:, 1]
fpr4, tpr4, thresholds4 = roc_curve(y_test, xgb_prob)
roc_auc4 = auc(fpr4, tpr4)

lw = 2
plt.figure(figsize=(10, 8))
plt.plot(fpr1, tpr1,color='red',label='ROC KNN (AUC = %0.2f, ACC = %0.2f)' % (roc_auc1, knn_accuracy))
plt.plot(fpr2, tpr2,color='blue',label='ROC Decision Tree (AUC = %0.2f, ACC = %0.2f)' % (roc_auc2, dt_accuracy))
plt.plot(fpr3, tpr3,color='green',label='ROC RF (AUC = %0.2f, ACC = %0.2f)' % (roc_auc3, rf_accuracy))
plt.plot(fpr4, tpr4,color='orange',label='ROC XGBOOST (AUC = %0.2f, ACC = %0.2f)' % (roc_auc4, xgb_accuracy))

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve ')
plt.xlabel('(1 - Specificity)')
plt.ylabel('(Sensitivity)')
plt.grid(True)
plt.legend(loc="lower right")
plt.show()

print("XGBOOST model has\ higher probability of accurate prediction as compared to KNN, Decision Tree and Random Forest")
# Out:
# XGBOOST model has\ higher probability of accurate prediction as compared to KNN, Decision Tree and Random Forest

# %%
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }

# %%
xgb = XGBClassifier(learning_rate=0.02, n_estimators=600, objective='binary:logistic',
                    silent=True, nthread=1)

# %%
folds = 3
param_comb = 5

skf = StratifiedKFold(n_splits=folds, shuffle = True, random_state = 1001)

random_search = RandomizedSearchCV(xgb, param_distributions=params, n_iter=param_comb, scoring='roc_auc', n_jobs=4, cv=skf.split(x,y), verbose=3, random_state=1001 )

# Here we go
# start_time = timer(None) # timing starts from this point for "start_time" variable
random_search.fit(x, y)
# timer(start_time) # timing ends here for "start_time" variable
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  15 out of  15 | elapsed:   14.3s finished
# [22:41:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:41:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
print('\n Best estimator:')
print(random_search.best_estimator_)
print('\n Best normalized gini score for %d-fold search with %d parameter combinations:' % (folds, param_comb))
print(random_search.best_score_ * 2 - 1)
print('\n Best hyperparameters:')
print(random_search.best_params_)
# Out:
#  Best estimator:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1.0, gamma=5, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.02, max_delta_step=0, max_depth=3,
#               min_child_weight=5, missing=nan, monotone_constraints='()',
#               n_estimators=600, n_jobs=1, nthread=1, num_parallel_tree=1,
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               silent=True, subsample=1.0, tree_method='exact',
#               validate_parameters=1, verbosity=None)
#
#  Best normalized gini score for 3-fold search with 5 parameter combinations:
# 0.7269733876717634
#
#  Best hyperparameters:
# {'subsample': 1.0, 'min_child_weight': 5, 'max_depth': 3, 'gamma': 5, 'colsample_bytree': 1.0}

# %%
final_xgb = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=1.0, gamma=5, gpu_id=-1,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.02, max_delta_step=0, max_depth=3,
              min_child_weight=5, monotone_constraints='()',
              n_estimators=600, n_jobs=1, nthread=1, num_parallel_tree=1,
              random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
              silent=True, subsample=1.0, tree_method='exact',
              validate_parameters=1, verbosity=None)

final_xgb.fit(x_train, y_train, verbose=False) 
print("XGBClassifier Score :")
final_xgb.score(x_test,y_test)
# Out:
# [22:44:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [22:44:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier Score :
# 0.824

# %%
import pickle
with open ('FlightPricePrediction.sav','wb') as f:
    pickle.dump(final_xgb,f)
